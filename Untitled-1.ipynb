# %%
#get dataset from roboflow
#https://docs.roboflow.com/quickstart/download-dataset
from roboflow import Roboflow
rf = Roboflow(api_key="iCzv9zrDaKiku0sabIZs")
project = rf.workspace("fb-ej1di").project("football-players-detection-3zvbc-dcpes")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov8:: 100%|██████████| 756/756 [00:00<00:00, 2427.76it/s]

# %%
#train modle yolov8
from ultralytics import YOLO
import torch
torch.clear_autocast_cache()
model=YOLO("yolov8x.pt")
# !yolo task=detect mode=train model=yolov8x.pt data=D:/football_dêtction/football-players-detection-1/data.yaml epochs=100 batch=3
# Out:
# New https://pypi.org/project/ultralytics/8.3.94 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.93 🚀 Python-3.11.9 torch-2.8.0.dev20250317+cu128 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...

# %%
#main to run video
from r_video.video import save_video,read_video
from player.tracker import Tracker
from ultralytics import YOLO
def main():
    video_path = "D:/football_dêtction/input/mc.mp4"
    save_path = "D:/football_dêtction/output4"
    tracker = YOLO("D:/football_dêtction/runs/detect/train3/weights/best.pt")
    tracks=tracker.get_object_tracks(detect_frames,read_from_stubs=True,stubs_path='D:/football_dêtctionstubs')
    (video_path)
    save_video(video_path, save_path, model)
if __name__ == "__main__":
    main()
